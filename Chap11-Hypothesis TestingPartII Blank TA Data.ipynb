# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# # Graduate Student Data ##

# %%
scores = Table.read_table('scores_by_section.csv')
scores

# %%
#We want to group by section and find the mean of for each section

# %%
#Note here we cannot just find the avg of all the means to find the 
#average of the class since the class size can be different.
#Finding the mean from the original table

# %%
#Lets find out how many students were in section 3. 
#The GSI says that this 27 students are a random sample from the class.
#The students says this 13. is too low.

# %%
#For group 3 the midterm average is the observed average
observed_average =

# %%
#We are going to replicate under the null. We are replicating the class
#Thus each replication is going to be 27 students. Then find mean.
#Here we are sampling from the table so .sample is easy
random_sample =

# %%
random_sample =

# %%
averages = make_array()
repetitions = 10000

for i in np.arange(repetitions):

# %%
Table().with_column('Random Sample Average', averages).hist(bins = 25)
plots.scatter(observed_average, 0, color = 'red', s=40);

# %%
sum(averages <= observed_average) / repetitions

# %%
Table().with_column('Random Sample Average', averages).hist(bins = 25)
plots.scatter(observed_average, 0, color='red', s=30)
plots.plot([13.67, 13.67], [0, 0.35], color='green', lw=2);
