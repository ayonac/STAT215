# %%
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np

# %%
s=make_array(1,7, 3, 9, 5)

# %%
percentile()

# %% [markdown]
# To find the percentile, arrange your observations in ascending order. Calculate $(p/100)*n$, where $p$ is the percentile and $n$ is the sample size. Round to the next largest integer. The observation is that position is your percentile.

# %%
(10/100)*5

# %% [markdown]
# Check if the 39th percentile is the same as the 40th percentile

# %%
percentile(41, s)==percentile(40, s)

# %%
sf = Table.read_table('san_francisco_2015.csv')

# %%
sf

# %%
#Then the mayor of SF was ED Lee

# %%
#You will notice we have some negative numbers - can happen when people move between jobs.
#These people leave. Lets just look at the people who were half time employeed.

# %%
#Assuming 10$ min pay, and worked 20 hours a week and for the year

# %%
#These are just the people working at least half time
sf = sf.where('Salaries', are.above(10000))

# %%
#Thus we have about 36500 people which is our population. We are going to next take a sample
#Work with a sample and estimate a median and see if this is good enough. 
sf.num_rows

# %%
#Here we will pretend that the population median is unknown. 
pop_median=

# %%
sf_bins= np.arange(0, 700000, 25000)
sf.hist('Total Compensation', bins = sf_bins)

# %%
#Lets pretend we did not have the population, 
#draw a random sample of size 300 from the population and call it our_sample
our_sample =

# %%
our_sample.hist()

# %%
est_median=

# %%
#How can we draw another sample - we can today go back to the pop and draw another sample
#But we would have used up our resurces so we just have one sample. This is bootstrap sampling
#Here we do not have to specify the sample size in the () as by default it is the same size

# %%
#WE are defining a function here to do lots of bootstrap samples

# %%
bstrap_medians = bootstrap_median(our_sample, 'Total Compensation', 5000)

# %%
left =

# %%
right =

# %%
#This is the bootstrap emprirical distribution for the median
