# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Swain Vs Alabama

# %%
population_proportion = 
population_proportion

# %%
sample_proportions()

# %%
def panel_proportion():

# %%
panel_proportion()

# %%
panels = make_array()

for i in np.arange():
    new_panel = 
    panels =

# %%
panels

# %%
Table().with_column(
    'Number of Black Men on Panel of 100', panels
).hist(bins =np.arange(5,40))
plots.ylim(-0.002, 0.09)
plots.scatter(8,0, color = 'red', s = 40);

# %% [markdown]
# ## Mendel's Pea Experiment

# %%
#Mendel had a total of 929 plants of which 709 had purple flowers
observed_purple = (709/929)*100
observed_purple

# %%
model_proportions =

# %%
def purple_flowers():

# %%
purple_flowers()

# %%
Table().with_column('Percent Purple Flowers', purples).hist()
plots.ylim(-0.02, 0.25)
plots.scatter(observed_purple, 0, color = 'red', s = 40);
