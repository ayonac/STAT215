# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
from datascience import Table

# %%
nba=

# %%
# Suppose I want to group players by their positions and just see the count. 
position =

# %% [markdown]
# Now suppose you want to see how much moneyon average each position earned

# %% [markdown]
# ### Simple Lists <br>
# Lists are lot like arrays, they are a bit different. Its a sequence of values, but all values does not have to be of the same type. You can nest lists and arrays, so a list and have arrays. In python square brackets denote lists.

# %%
#Example of a list
[2, 2, 2+3, 'four']

# %%
#Creating a Table with lists
Table().with_columns('Numbers', [1,2,3,4])

# %%
#I am creating a table with just the names of the columns 
drinks = Table(['Drink', 'Cafe', 'Price'])
drinks

# %%
#Above is an empty table and now we can add rows to it (new), just like columns
drinks= drinks.with_rows([
    ['Latte', 'Starbucks', 4.5 ],
    ['Tea', 'Starbucks', 3.5],
    ['Espresso', 'UCafe', 3.25],
    ['Latte', 'UCafe', 4.25]
    ])
drinks

# %% [markdown]
# ## Grouping with two columns

# %%
cones =

# %%
c =

# %%
cones.pivot('Flavor', 'Color', values = 'Price', collect = np.average)

# %% [markdown]
# ## Thought Questions

# %%
sky = Table.read_table('skyscrapers_v2.csv')
sky

# %% [markdown]
# Discussion question - For each city what is the height of the tallest building for each material?

# %% [markdown]
# ## Join
