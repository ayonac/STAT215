# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Mothers and Smoking ##

# %%
baby = 
baby

# %%
smoking_and_birthweight =

# %%
#Group by smoking status to find the count in each group

# %%
#Create a visualization for the data

# %%
#Find the mean birth weight of babies for each group based on Maternal Smoker status.
means_table =

# %%
#Store the difference between the two means in a variable observed difference
means = 
observed_difference = 
observed_difference

# %%
weights= smoking_and_birthweight.select('Birth Weight')
weights

# %%
#Lets shuffle the weights and store in an array
shuffled_weights =

# %%
original_and_shuffled =

# %%
shuffled_weights = 
shuffled_tbl = 
means_tbl = 
means_tbl.column(2).item(0)-means_tbl.column(2).item(1)

# %%
differences = make_array()

for i in np.arange(5000):

# %%
Table().with_column('Difference Between Means', differences).hist(bins = 20)
plots.scatter(observed_difference, 0.01, color = 'red', s=40);
